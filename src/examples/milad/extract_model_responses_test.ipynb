# %%
import json
import torch 
from utils_milad import set_seed

set_seed(0)



with open("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/hallucination_metrics_llava_pope_test_eval_no_steer_adversarial_-1_model_prediction.json") as f:
    adversarial = json.load(f)
adversarial_reps_neg = torch.load("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/features/save_hidden_states_for_l2s_llava_pope_test_features_neg_answers_14_adversarial_all_test_-1.pth")
adversarial_reps_pos = torch.load("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/features/save_hidden_states_for_l2s_llava_pope_test_features_pos_answers_14_adversarial_all_test_-1.pth")

with open("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/hallucination_metrics_llava_pope_test_eval_no_steer_popular_-1_model_prediction.json") as f:
    popular = json.load(f)
popular_reps = torch.load("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/features/save_hidden_states_for_l2s_llava_pope_test_features_neg_answers_14_popular_all_test_-1.pth")
popular_reps_pos = torch.load("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/features/save_hidden_states_for_l2s_llava_pope_test_features_pos_answers_14_popular_all_test_-1.pth")
with open("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/hallucination_metrics_llava_pope_test_eval_no_steer_random_-1_model_prediction.json") as f:
    random = json.load(f)
random_reps = torch.load("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/features/save_hidden_states_for_l2s_llava_pope_test_features_neg_answers_14_random_all_test_-1.pth")
random_reps_pos = torch.load("/research/hal-afsharim/learn-to-steer/Hallucination/POPE/hallucination/features/save_hidden_states_for_l2s_llava_pope_test_features_pos_answers_14_random_all_test_-1.pth")

# %%
adversarial_reps_neg["hidden_states"][0]['language_model.model.layers.14']["inputs"]["last_raw_input"]
# Out:
# tensor([[True, True, True,  ..., True, True, True]])

# %%
print(adversarial["predictions"][0])
print(adversarial["response"][0][0])
print(popular["predictions"][0])
print(popular["response"][0])
print(random["predictions"][0])
print(random["response"][0])
# Out:
# ['Yes, there is a man in the image who is catching a frisbee.']
# yes
# ['Yes, there is a man in the image who is catching a frisbee.']
# ['yes']
# ['Yes, there is a man in the image who is catching a frisbee.']
# ['yes']

# %%
# write code to check if adversarial["response"][i]/lower in adversarial["predictions"][i]/lower for i in range(len(adversarial["predictions"]))


for name,data in zip(["Adversarial", "Popular", "Random"], [adversarial, popular, random]):
    hal= []
    nonhal = []
    for i in range(len(data["predictions"])):
        if data["response"][i][0].lower() in data["predictions"][i][0].lower():
            nonhal.append(i)
        else:
            hal.append(i)
            
    print(f"{name}: {len(hal)} hallucinated, {len(nonhal)} non-hallucinated, Percentage hallucinated: {len(hal)/len(data['predictions'])*100:.2f}%")
# Out:
# Adversarial: 246 hallucinated, 944 non-hallucinated, Percentage hallucinated: 20.67%
# Popular: 221 hallucinated, 974 non-hallucinated, Percentage hallucinated: 18.49%
# Random: 199 hallucinated, 998 non-hallucinated, Percentage hallucinated: 16.62%

# %%
944+974+998
# Out:
# 2916

# %%
1195
